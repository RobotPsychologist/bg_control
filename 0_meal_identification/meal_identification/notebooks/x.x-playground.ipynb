# %%
import pandas as pd
import numpy as np
import os
import sys

sys.path.append(os.path.abspath("../meal_identification"))

from DatasetGenerator import *
from DatasetCleaner import *

# %%
sample_csv_path = r"/Users/andrewyang/Projects/bg_control/0_meal_identification/meal_identification/data/interim/2024-10-30_500030__timeInter5mins_dayStart4hrs_minCarb10g_3hrMealW.csv"

df = pd.read_csv(sample_csv_path)

# %%
(df.shape[0]-df['affects_fob'].isnull().sum())/df.shape[0]
# Out:
# np.float64(0.03109903381642512)

# %%
df.columns.sort_values().tolist()
# Out:
# ['affects_fob',
#  'affects_iob',
#  'bgl',
#  'bgl_i',
#  'date',
#  'day_start_shift',
#  'dose_units',
#  'food_g',
#  'food_g_keep',
#  'food_glycemic_index',
#  'msg_type']

# %%
[print(index) for index, val in enumerate(df['bgl'].isnull()) if val == True]

# polynomial interpolation
# df['bgl_i'] = df['bgl'].interpolate(method='polynomial', order=3)
# df['bgl'].isnull()[0]
# Out:
# 1013
# 1014
# 1015
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 3081
# 3643
# 3644
# 3775
# 3776
# 3777
# 4469
# 4470
# 4830
# 5242
# 6276
# 6627
# 6628
# 6723
# 6724
# 6730
# 6731
# 6817
# 6861
# 6862
# 6863
# 6864
# 6865
# 6869
# 6870
# 6872
# 6873
# 6874
# 6875
# 6878
# 6966
# 7068
# 7409
# 8097
# 8142
# 8324
# 8599
# 8650
# 8651
# 8654
# 8843
# 8932
# 8933
# 9192
# 9198
# 9199
# 9202
# 9211
# 9212
# 9271
# 9289
# 9290
# 9298
# 9304
# 9317
# 9319
# 9320
# 9321
# 9324
# 9326
# 9327
# 9330
# 9335
# 9339
# 9340
# 9341
# 9342
# 9343
# 9349
# 9353
# 9354
# 9357
# 9358
# 9359
# 9360
# 9363
# 9364
# 9365
# 9370
# 9371
# 9372
# 9373
# 9374
# 9378
# 9384
# 9387
# 9389
# 9391
# 9392
# 9393
# 9394
# 9397
# 9398
# 9399
# 9401
# 9402
# 9403
# 9405
# 9406
# 9407
# 9408
# 9409
# 9410
# 9412
# 9413
# 9414
# 9415
# 9416
# 9417
# 9418
# 9419
# 9420
# 9421
# 9422
# 9423
# 9428
# ...

# %%
# iterate every column and find missing values
missing_values = df.isnull()
# Out:
# date                       0
# bgl                      905
# msg_type               25732
# affects_fob            25672
# affects_iob            25672
# dose_units             25886
# food_g                 16550
# food_glycemic_index    26335
# food_g_keep            25957
# day_start_shift            0
# dtype: int64
